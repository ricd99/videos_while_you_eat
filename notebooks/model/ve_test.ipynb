# %% [markdown]
# ## config

# %%
import numpy as np
import pandas as pd
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MultiLabelBinarizer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
import matplotlib.pyplot as plt
import re

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA

import json
import glob

from googleapiclient.discovery import build

# %%
pd.set_option('display.float_format', '{:.4f}'.format)

# %%
with open ("../../performative.txt", "r") as f:
    lines = f.readlines()
    API_KEY = lines[2].strip()
    
yt = build("youtube", "v3", developerKey=API_KEY)

# %% [markdown]
# ## selecting features

# %%
df_initial = pd.read_json("../../data/processed/ve_channels/ve.json")

# %%
df_initial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 252 entries, 0 to 251
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   channel_id    251 non-null    object
#  1   channel_name  251 non-null    object
# dtypes: object(2)
# memory usage: 5.9+ KB

# %%
df_initial.iloc[141]
# Out:
# channel_id      None
# channel_name    None
# Name: 141, dtype: object

# %%
df_initial = df_initial.drop(index=141)
df_initial = df_initial.reset_index(drop=True)

# %%
df_initial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   channel_id    251 non-null    object
#  1   channel_name  251 non-null    object
# dtypes: object(2)
# memory usage: 4.1+ KB

# %%
resp = yt.channels().list(
    part="brandingSettings,contentDetails,id,localizations,snippet,statistics,status,topicDetails",
    id="UCqgh7QNlVV8kv3LBTJZYWrg"
).execute()

print(json.dumps(resp["items"][0], indent=2))
# Out:
# {
#   "kind": "youtube#channel",
#   "etag": "YfB4ZubTSFlXDFFrPuPMDRmRvgE",
#   "id": "UCqgh7QNlVV8kv3LBTJZYWrg",
#   "snippet": {
#     "title": "The Film Essay",
#     "description": "A video essay channel devoted to making videos exploring cinema as a medium, the techniques used and all that lies beyond.\nLike me on Facebook!    https://www.facebook.com/Thefilmessay/?ref=aymt_homepage_panel\n\nFor all business-related enquires: thefilmessay@gmail.com\n",
#     "customUrl": "@thefilmessay9832",
#     "publishedAt": "2016-08-16T14:09:38Z",
#     "thumbnails": {
#       "default": {
#         "url": "https://yt3.ggpht.com/ytc/AIdro_lCt-zJAeXGbrNbcp9eMhre6sOT-_Omf7nvVuUdftpJBw=s88-c-k-c0x00ffffff-no-rj",
#         "width": 88,
#         "height": 88
#       },
#       "medium": {
#         "url": "https://yt3.ggpht.com/ytc/AIdro_lCt-zJAeXGbrNbcp9eMhre6sOT-_Omf7nvVuUdftpJBw=s240-c-k-c0x00ffffff-no-rj",
#         "width": 240,
#         "height": 240
#       },
#       "high": {
# ...

# %%
print(json.dumps(resp["items"], indent=2))
# Out:
# [
#   {
#     "kind": "youtube#channel",
#     "etag": "YfB4ZubTSFlXDFFrPuPMDRmRvgE",
#     "id": "UCqgh7QNlVV8kv3LBTJZYWrg",
#     "snippet": {
#       "title": "The Film Essay",
#       "description": "A video essay channel devoted to making videos exploring cinema as a medium, the techniques used and all that lies beyond.\nLike me on Facebook!    https://www.facebook.com/Thefilmessay/?ref=aymt_homepage_panel\n\nFor all business-related enquires: thefilmessay@gmail.com\n",
#       "customUrl": "@thefilmessay9832",
#       "publishedAt": "2016-08-16T14:09:38Z",
#       "thumbnails": {
#         "default": {
#           "url": "https://yt3.ggpht.com/ytc/AIdro_lCt-zJAeXGbrNbcp9eMhre6sOT-_Omf7nvVuUdftpJBw=s88-c-k-c0x00ffffff-no-rj",
#           "width": 88,
#           "height": 88
#         },
#         "medium": {
#           "url": "https://yt3.ggpht.com/ytc/AIdro_lCt-zJAeXGbrNbcp9eMhre6sOT-_Omf7nvVuUdftpJBw=s240-c-k-c0x00ffffff-no-rj",
#           "width": 240,
# ...

# %% [markdown]
# feature columns

# %%
features = resp["items"][0]
features["snippet"]["title"]
features["snippet"]["description"]
features["snippet"]["country"]
features["topicDetails"]["topicCategories"]
features["brandingSettings"]["channel"]["keywords"]
videos = features["contentDetails"]["relatedPlaylists"]["uploads"]

# %%
resp_vids = yt.playlistItems().list(
    part="contentDetails,id,snippet,status",
    playlistId=videos, 
).execute()

# %%
print(json.dumps(resp_vids["items"], indent=2))
# Out:
# [
#   {
#     "kind": "youtube#playlistItem",
#     "etag": "SDGLDt-RgAs0tvD4PvWKtlOpkjE",
#     "id": "VVVxZ2g3UU5sVlY4a3YzTEJUSlpZV3JnLmlBUDZIbXA4N1hN",
#     "snippet": {
#       "publishedAt": "2026-02-06T17:13:58Z",
#       "channelId": "UCqgh7QNlVV8kv3LBTJZYWrg",
#       "title": "The Hidden Philosophy Lesson in The Before Trilogy (Richard Linklater)",
#       "description": "Richard Linklater\u2019s Before trilogy and Alain de Botton\u2019s Essays in Love both peel back the fantasy of romance to reveal something deeper: love as a lifelong negotiation between two imperfect people. \n\n#beforesunrise #beforesunset #beforemidnight #richardlinklater #EssaysInLove #alaindebotton  #philosophy   #loveexplained  #movieanalysis #relationshipadvice #cinemalovers  #shorts",
#       "thumbnails": {
#         "default": {
#           "url": "https://i.ytimg.com/vi/iAP6Hmp87XM/default.jpg",
#           "width": 120,
#           "height": 90
#         },
#         "medium": {
# ...

# %%
features = resp_vids["items"][1]  #using second video cause first was a short
features["snippet"]["title"]
features["snippet"]["description"]
# Out:
# "Christopher Nolan has become one of cinema’s most distinctive directors, known for his fragmented, non‑linear narratives and time‑bending storytelling. In this video, I break down how Nolan uses structure, parallel timelines, and temporal manipulation to create immersion, emotion, and scale across films like Inception, Memento, Interstellar, Tenet, Dunkirk, and The Prestige.\n\nFrom puzzle‑box narratives to layered timelines, Nolan turns time into a narrative engine—shaping character psychology, building tension, and transforming action into metaphor. His films challenge the audience to piece together meaning, creating a unique blend of blockbuster spectacle and art‑film experimentation. I explore how he uses structure as a sensory experience, why his stories feel so grand, and how his manipulation of time deepens themes of memory, identity, obsession, and love.\n\nWith The Odyssey on the horizon, we look at how Nolan’s signature style might evolve within a mythic framework.\n\n#chr
# ...

# %% [markdown]
# ## data collection script

# %%
def get_channel_features(yt, channel_id):
    resp = yt.channels().list(
        part = "brandingSettings,contentDetails,snippet,topicDetails",
        id=channel_id
    ).execute()

    if not resp.get("items"):
        print(f"could not find channel: {channel_id}")
        return None
    
    ch = resp["items"][0]

    snippet = ch.get("snippet", {})
    topic = ch.get("topicDetails", {})
    branding = ch.get("brandingSettings", {}).get("channel", {})
    uploads_playlist = ch.get("contentDetails", {}).get("relatedPlaylists", {})

    return {
        "title": snippet.get("title"),
        "description": snippet.get("description"),
        "country": snippet.get("country"),
        "topics": topic.get("topicCategories"),
        "keywords": branding.get("keywords"),
        "uploads": uploads_playlist.get("uploads")
    }

# %%
def get_video_features(yt, uploads, max_videos=10):
    videos = []
    next_page = None

    while len(videos) < max_videos:
        resp = yt.playlistItems().list(
            part="snippet",
            playlistId=uploads,
            maxResults=50,
            pageToken=next_page
        ).execute()

        for item in resp["items"]:
            if len(videos) >= max_videos:
                break

            snippet = item["snippet"]
            description = snippet.get("description", "")
            if "#shorts" in description.lower():
                continue

            videos.append({
                "title":        snippet.get("title"),
                "description":  description,
            })

        next_page = resp.get("nextPageToken")
        if not next_page:
            break
    return videos

# %%
def get_all_features(yt, channel_id):
    features = get_channel_features(yt, channel_id)
    if features is None:
        return None
    
    videos = get_video_features(yt, features["uploads"])
    features["videos"] = videos
    return features

# %%
success = []
failed = []

for i, row in df_initial.iterrows():   # bottlenecked as playlistItems only supports one playlist id at a time so iterrows is fine
    print(f"Fetching #{i}: {row["channel_name"]}")
    features = get_all_features(yt, row["channel_id"])
    if features is None:
        failed.append((row["channel_id"], row["channel_name"]))
        continue
    success.append({"channel_id": row["channel_id"], "channel_name": row["channel_name"], **features})
# Out:
# Fetching: The Film Essay
# Fetching: Every Frame a Painting
# Fetching: Nikki Carreon
# Fetching: Action Button
# Fetching: Thomas Flight
# Fetching: Full Fat Videos
# Fetching: You Have Been Watching Films
# Fetching: Lancelloti
# Fetching: Quinton Reviews
# Fetching: About Movies
# Fetching: Moviewise
# Fetching: The Thrifty Typewriter
# Fetching: Movies With Mitchell
# Fetching: Screened
# Fetching: Cinema Sensationalist
# Fetching: cinelumi
# Fetching: Mr. Films
# Fetching: Enchanted Essays
# Fetching: Final Girl Digital
# Fetching: Alex Meyers
# Fetching: Movies Under The Surface
# Fetching: Movie Notepad
# Fetching: Reading Between the Frames
# Fetching: The Armchair Auteur
# Fetching: Reflections on Film
# Fetching: Sonny Rossiter
# Fetching: CinemaStix
# Fetching: Midnight Showing
# Fetching: Friendly Space Ninja
# Fetching: José
# Fetching: Noah Caldwell-Gervais
# Fetching: The Lazy Critic
# Fetching: Film Companion Reviews
# Fetching: Sandwich Reviews
# ...

# %%
df_initial[df_initial["channel_name"]=="Paper Will"]
# Out:
#                    channel_id channel_name
# 140  UCPwuva5LbnwFTetkP_cUQHA   Paper Will

# %%
df_initial.iloc[141]
# Out:
# channel_id      None
# channel_name    None
# Name: 141, dtype: object

# %%
print(len(success))
print(len(failed))

# %%
df = pd.DataFrame(success)
df
