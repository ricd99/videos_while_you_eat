# %%
from pathlib import Path
import pandas as pd

# %%
base = Path.cwd()
base
# Out:
# WindowsPath('c:/Users/ryanh/code/projects/ytrec/notebooks')

# %%
data = base.parent / "data" / "processed" / "channels_pp.csv"
df = pd.read_csv(data)

# %%
df.shape
df.head()
# Out:
#                  channel_id            channel_name  \
# 0  UCqgh7QNlVV8kv3LBTJZYWrg          The Film Essay
# 1  UCjFqcJQXGZ6T6sxyFB-5i6A  Every Frame a Painting
# 2  UCr8r7UVsDaRiIQSVUHVBd_A           Nikki Carreon
# 3  UCjKSoJlPgcK6BmoSqXpj5xQ           Action Button
# 4  UCUyvQV2JsICeLZP4c_h40kA           Thomas Flight
#
#                                          description  \
# 0  A video essay channel devoted to making videos...
# 1  Taylor & Tony are gone again! Thanks for watch...
# 2  Hello!! Just here making silly stuff, making s...
# 3  patreon.com/actionbutton\ntwitch.tv/actionbutt...
# 4  Exploring the artistry behind cinema, TV, and ...
#
#                                               topics  \
# 0            Television program, Film, Entertainment
# 1         Lifestyle (sociology), Entertainment, Film
# 2         Lifestyle (sociology), Entertainment, Film
# 3  Role-playing video game, Action-adventure game...
# 4         Entertainment, Film, Lifestyle (sociology)
#
# ...

# %% [markdown]
# results for mentour pilot

# %%
df[df["channel_name"] == "The Sin Squad"]
# Out:
#                    channel_id   channel_name  \
# 184  UCNpkJ9sQUkmXoFrXBwi7XxA  The Sin Squad
#
#                                            description  \
# 184  The Sin Squad: Looking too closely at (mostly ...
#
#                                          topics  \
# 184  Lifestyle (sociology), Entertainment, Film
#
#                                               keywords  \
# 184  animation reviews animation analysis media ana...
#
#                                                 videos
# 184  The Frozen 2 Soundtrack is Worse Than You Thin...

# %%
df[df["channel_name"] == "I Finished A Video Game"]
# Out:
#                    channel_id             channel_name  \
# 106  UCVdDUN69YsAXPxh2y71sMtQ  I Finished A Video Game
#
#                                            description  \
# 106  Extremely detailed videos about the beautiful ...
#
#                                                 topics  \
# 106  Action game, Role-playing video game, Video ga...
#
#                                               keywords  \
# 106  Action game, Role-playing video game, Video ga...
#
#                                                 videos
# 106  Live Roasting The Half Life Video (and talking...

# %%
df[df["channel_name"] == "Cartoonshi シ"]
# Out:
#                    channel_id  channel_name  \
# 231  UCkaP2qh7t1Dc6LNzytNrf9g  Cartoonshi シ
#
#                                            description  \
# 231  I live off of hot chocolate and I might hate e...
#
#                                       topics  \
# 231  Television program, Entertainment, Film
#
#                                     keywords  \
# 231  Television program, Entertainment, Film
#
#                                                 videos
# 231  The END of Smiling Friends... Will Toy Story 5...

# %%
df[df["channel_name"] == "LEMMiNO"]
# Out:
#                    channel_id channel_name  \
# 143  UCRcgy6GzDeccI7dkbbBna3Q      LEMMiNO
#
#                                            description  \
# 143  Long-form videos about space and mysteries and...
#
#                                                 topics  \
# 143  documentary documentaries mysteries mystery vi...
#
#                                               keywords  \
# 143  documentary documentaries mysteries mystery vi...
#
#                                                 videos
# 143  Shouting at Stars: A History of Interstellar M...

# %%
df[df["channel_name"] == "pey talks anime"]
# Out:
#                    channel_id     channel_name  \
# 217  UCvjaYSxQ9DLQBSrurmhEjiQ  pey talks anime
#
#                                            description               topics  \
# 217  For business inquires email peytalks@gmail.com...  Film, Entertainment
#
#                 keywords                                             videos
# 217  Film, Entertainment  When motive and identity collide Frieren's sec...

# %%
df.columns
# Out:
# Index(['channel_id', 'channel_name', 'description', 'topics', 'keywords',
#        'videos'],
#       dtype='object')
