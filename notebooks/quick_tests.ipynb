# %%
import os
os.chdir(r"C:\Users\ryanh\code\projects\ytrec")

# %%
RAW = "data/processed/ve_channels/ve_with_features.json"
df = pd.read_json(RAW)

# %%
df.head()
# Out:
#                  channel_id            channel_name                   title  \
# 0  UCqgh7QNlVV8kv3LBTJZYWrg          The Film Essay          The Film Essay
# 1  UCjFqcJQXGZ6T6sxyFB-5i6A  Every Frame a Painting  Every Frame a Painting
# 2  UCr8r7UVsDaRiIQSVUHVBd_A           Nikki Carreon           Nikki Carreon
# 3  UCjKSoJlPgcK6BmoSqXpj5xQ           Action Button           Action Button
# 4  UCUyvQV2JsICeLZP4c_h40kA           Thomas Flight           Thomas Flight
#
#                                          description country  \
# 0  A video essay channel devoted to making videos...      GB
# 1  Taylor & Tony are gone again! Thanks for watch...    None
# 2  Hello!! Just here making silly stuff, making s...      US
# 3  patreon.com/actionbutton\ntwitch.tv/actionbutt...    None
# 4  Exploring the artistry behind cinema, TV, and ...    None
#
#                                               topics  \
# 0  [https://en.wikipedia.org/wiki/Television_prog...
# ...

# %%
df.shape
# Out:
# (251, 9)

# %%
OUT = "data/preprocessed/channels_pp.csv"
df_out = pd.read_csv(OUT)

# %%
df_out.head()
# Out:
#                  channel_id            channel_name country  \
# 0  UCqgh7QNlVV8kv3LBTJZYWrg          The Film Essay     NaN
# 1  UCjFqcJQXGZ6T6sxyFB-5i6A  Every Frame a Painting     NaN
# 2  UCr8r7UVsDaRiIQSVUHVBd_A           Nikki Carreon     NaN
# 3  UCjKSoJlPgcK6BmoSqXpj5xQ           Action Button     NaN
# 4  UCUyvQV2JsICeLZP4c_h40kA           Thomas Flight     NaN
#
#                                                 text
# 0  A video essay channel devoted to making videos...
# 1  Taylor & Tony are gone again! Thanks for watch...
# 2  Hello!! Just here making silly stuff, making s...
# 3  patreon.com/actionbutton\ntwitch.tv/actionbutt...
# 4  Exploring the artistry behind cinema, TV, and ...
